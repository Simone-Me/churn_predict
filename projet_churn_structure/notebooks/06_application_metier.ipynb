# %% [markdown]
# # 07 - Application metier
#
# Ce notebook explique ce que fait `app.py`. Le dashboard reste en `.py` parce que Streamlit fonctionne naturellement avec un script Python.

# %% [markdown]
# ## Lancer le dashboard
#
# Depuis le dossier projet :
#
# ```powershell
# streamlit run app.py
# ```

# %%
from pathlib import Path
BASE_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
print('Commande a lancer :')
print(f'cd "{BASE_DIR}"')
print('streamlit run app.py')
# Out:
# Commande a lancer :
# cd "c:\Users\Héctor\OneDrive\Desktop\Projects\EFREI\M1-DE\PRO_DATA_SCIENCE\churn_predict\projet_churn_structure"
# streamlit run app.py

# %% [markdown]
# ## Pourquoi un seul modele dans l application ?
#
# Pour un utilisateur metier, le choix du modele n est pas utile. Il veut seulement savoir quels clients sont a risque. L application utilise donc directement le modele retenu : Logistic Regression.

# %% [markdown]
# ## Ce que montre le dashboard
#
# - KPI de retention
# - clients a prioriser
# - revenu mensuel a risque
# - simulation client
# - explication des variables importantes
