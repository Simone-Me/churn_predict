# %% [markdown]
# # 04 - Utilisation du dashboard
#
# Objectif : comprendre comment lancer et presenter le dashboard Streamlit.

# %% [markdown]
# ## Lancer le dashboard
#
# Depuis le dossier du projet, executer :
#
# ```powershell
# streamlit run app.py
# ```
#
# Le dashboard permet de visualiser les KPI, simuler un client, comparer les modeles et expliquer les variables importantes.

# %%
from pathlib import Path
BASE_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
print('Dossier projet :', BASE_DIR)
print('Commande : streamlit run app.py')

# %% [markdown]
# ## Ce qu il faut montrer en presentation
#
# 1. La page Vue metier : nombre de clients, churn observe, clients a risque, revenu a risque.
# 2. La simulation client : modifier l activite, le support ou la satisfaction et observer la probabilite.
# 3. La comparaison modeles : montrer que le choix final se base sur le recall.
# 4. L explicabilite : montrer les variables qui influencent le modele.

# %% [markdown]
# ## Phrase simple
#
# "Le dashboard transforme le modele en outil de decision : il ne donne pas seulement un score, il aide a prioriser les clients a contacter."
